# %%
! pip install pymilvus milvus sentence-transformers
# Out:
# Requirement already satisfied: pymilvus in /Users/ashleylrice/songsD/lib/python3.9/site-packages (2.5.4)
# Requirement already satisfied: milvus in /Users/ashleylrice/songsD/lib/python3.9/site-packages (2.3.9)
# Requirement already satisfied: sentence-transformers in /Users/ashleylrice/songsD/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: ujson>=2.0.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: milvus-lite>=2.4.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (2.4.11)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (5.29.3)
# Requirement already satisfied: pandas>=1.2.4 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (2.2.3)
# Requirement already satisfied: setuptools>69 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pymilvus) (75.8.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (4.48.2)
# Requirement already satisfied: scikit-learn in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: tqdm in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scipy in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: filelock in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: packaging>=20.9 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pandas>=1.2.4->pymilvus) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: six>=1.5 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Requirement already satisfied: networkx in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.5)
# Requirement already satisfied: sympy==1.13.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ashleylrice/songsD/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Users/ashleylrice/songsD/bin/python3 -m pip install --upgrade pip' command.

# %%
# Step 1: Import required libraries
from sentence_transformers import SentenceTransformer
from milvus import default_server
from pymilvus import connections, utility, FieldSchema, CollectionSchema, DataType, Collection
from time import time

# %%
default_server.start()
connections.connect(host="127.0.0.1", port=default_server.listen_port)

# %%
from sentence_transformers import SentenceTransformer

# Load the models
v12 = SentenceTransformer("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")
ft3_v12 = SentenceTransformer("Sprylab/paraphrase-multilingual-MiniLM-L12-v2-fine-tuned-3")
ft5_v12 = SentenceTransformer("hroth/psais-paraphrase-multilingual-MiniLM-L12-v2-5shot")

# %%
# Define dimension constant
DIMENSION = 384

# Define schema
fields = [
    FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=True),
    FieldSchema(name="sentence", dtype=DataType.VARCHAR, max_length=500),
    FieldSchema(name="embedding", dtype=DataType.FLOAT_VECTOR, dim=DIMENSION),
]
schema = CollectionSchema(fields=fields)
collection_v12 = Collection(name="collection_v12", schema=schema)
collection_v12_ft5 = Collection(name="collection_v12_ft5", schema=schema)

# %%
# inspired by Speak Now (Taylor's Version)
# Lyrics from: Speak Now, Starlight, Sparks Fly, Haunted
sentences = [
"I am not the kind of girl, who should be rudely barging in on a white veil occasion, but you are not the kind of boy who should be marrying the wrong girl",
"I sneak in and see your friends and her snotty little family all dressed in pastel and she is yelling at a bridesmaid somewhere back inside a room wearing a gown shaped like a pastry",
"This is surely not what you thought it would be.",
"I lose myself in a daydream where I stand and say, 'Don't say yes, run away now I'll meet you when you're out of the church at the back door.'",
"Don't wait, or say a single vow you need to hear me out and they said, 'Speak now'.",
"Fond gestures are exchanged.",
"And the organ starts to play a song that sounds like a death march.",
"And I am hiding in the curtains, it seems that I was uninvited by your lovely bride-to-be.",
"She floats down the aisle like a pageant queen.",
"But I know you wish it was me you wish it was me don't you?",
"I hear the preacher say, 'Speak now or forever hold your peace'",
"There's the silence, there's my last chance.",
"I stand up with shaky hands, all eyes on me",
"Horrified looks from everyone in the room but I'm only looking at you.",
"And you'll say, 'Let's run away now' I'll meet you when I'm out of my tux at the back door",
"Baby, I didn't say my vows So glad you were around When they said, 'Speak now'",
"I said, 'Oh my, what a marvelous tune'",
"It was the best night, never would forget how we moved.",
"The whole place was dressed to the nines and we were dancing, dancing like we're made of starlight",
"I met Bobby on the boardwalk summer of '45",
"Picked me up late one night out the window we were seventeen and crazy running wild, wild.",
"Can't remember what song he was playing when we walked in.",
"The night we snuck into a yacht club party pretending to be a duchess and a prince.",
"He said, 'Look at you, worrying so much about things you can't change You'll spend your whole life singing the blues If you keep thinking that way'",
"He was tryna to skip rocks on the ocean saying to me 'Don't you see the starlight, starlight don't you dream impossible things'",
"Ooh, ooh he's talking crazy Ooh, ooh dancing with me Ooh, ooh we could get married Have ten kids and teach 'em how to dream",
"The way you move is like a full on rainstorm.",
"And I'm a house of cards",
"You're the kind of reckless that should send me running but I kinda know that I won't get far",
"And you stood there in front of me just close enough to touch",
"Close enough to hope you couldn't see what I was thinking of",
"Drop everything now",
"Meet me in the pouring rain",
"Kiss me on the sidewalk",
"Take away the pain",
"'Cause I see sparks fly, whenever you smile",
"Get me with those green eyes, baby as the lights go down",
"Gimme something that'll haunt me when you're not around",
"My mind forgets to remind me you're a bad idea",
"You touch me once and it's really something you find I'm even better than you imagined I would be",
"I'm on my guard for the rest of the world but with you, I know it's no good"
"And I could wait patiently but I really wish you would"
"I run my fingers through your hair and watch the lights go wild",
"Just keep on keeping your eyes on me it's just wrong enough to make it feel right",
"And lead me up the staircase won't you whisper soft and slow, I'm captivated by you, baby like a fireworks show",
"You and I walk a fragile line I have known it all this time, But I never thought I'd live to see it break",
"It's getting dark and it's all too quiet And I can't trust anything now And it's coming over you like it's all a big mistake",
"Oh, I'm holding my breath Won't lose you again",
"Something's made your eyes go cold",
"Come on, come on, don't leave me like this I thought I had you figured out",
"Something's gone terribly wrong you're all I wanted",
"Can't breathe whenever you're gone can't turn back now, I'm haunted",
"I just know You're not gone, you can't be gone, no",
]

# %%
# Create embeddings
v12_embeds = {}
v12_q_embeds = {}
for sentence in sentences:
    v12_embeds[sentence] = v12.encode(sentence)
    v12_q_embeds[sentence] = ft5_v12.encode(sentence)

# Create index parameters
index_params = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 4},
}

# Create and load indices
collection_v12.create_index(field_name="embedding", index_params=index_params)
collection_v12.load()
collection_v12_ft5.create_index(field_name="embedding", index_params=index_params)
collection_v12_ft5.load()

# Insert data into collections
for sentence in sentences:
    v12_insert = [
        {
            "sentence": sentence,
            "embedding": v12_embeds[sentence]
        }
    ]
    ft_insert = [
        {
            "sentence": sentence,
            "embedding": v12_q_embeds[sentence]
        }
    ]
    
    collection_v12.insert(v12_insert)
    collection_v12_ft5.insert(ft_insert)

# Flush the collections
collection_v12.flush()
collection_v12_ft5.flush()

# %%
# Prepare search embeddings
search_embeds = {}
search_data = []
for sentence in sentences[0:2]:
    vector_embedding = ft3_v12.encode(sentence)
    search_embeds[sentence] = vector_embedding
    search_data.append(vector_embedding)

# Perform searches
start1 = time()
res_v12 = collection_v12.search(
    data=search_data,  # Embedded search value
    anns_field="embedding",  # Search across embeddings
    param={"metric_type": "L2",
           "params": {"nprobe": 2}},
    limit=3,  # Limit to top_k results per search
    output_fields=["sentence"])
time1 = time() - start1
print(f"Time for first search: {time1}")

start2 = time()
res_v12_ft5 = collection_v12_ft5.search(
    data=search_data,  # Embedded search value
    anns_field="embedding",  # Search across embeddings
    param={"metric_type": "L2",
           "params": {"nprobe": 2}},
    limit=3,  # Limit to top_k results per search
    output_fields=["sentence"])
time2 = time() - start2
print(f"Time for second search: {time2}")

# Print results
for i, hits in enumerate(res_v12):
    for hit in hits:
        print(f"Query sentence: {sentences[i]}")
        print(f"Nearest Neighbor Number {i}: {hit.entity.get('sentence')} ---- {hit.distance}\n")
# Out:
# Time for first search: 0.003366231918334961
# Time for second search: 0.0012531280517578125
# Query sentence: I am not the kind of girl, who should be rudely barging in on a white veil occasion, but you are not the kind of boy who should be marrying the wrong girl
# Nearest Neighbor Number 0: I am not the kind of girl, who should be rudely barging in on a white veil occasion, but you are not the kind of boy who should be marrying the wrong girl ---- 14.654441833496094
#
# Query sentence: I am not the kind of girl, who should be rudely barging in on a white veil occasion, but you are not the kind of boy who should be marrying the wrong girl
# Nearest Neighbor Number 0: I'm on my guard for the rest of the world but with you, I know it's no goodAnd I could wait patiently but I really wish you wouldI run my fingers through your hair and watch the lights go wild ---- 16.700664520263672
#
# Query sentence: I am not the kind of girl, who should be rudely barging in on a white veil occasion, but you are not the kind of boy who should be marrying the wrong girl
# Nearest Neighbor Number 0: Gimme something that'll haunt me when you're not around ---- 18.224519729614258
#
# Query sentence: I sneak in and see your friends and her snotty little family all dressed in pastel and she is yelling at a bridesmaid somewhere back inside a room wearing a gown shaped like a pastry
# Nearest Neighbor Number 1: I sneak in and see your friends and her snotty little family all dressed in pastel and she is yelling at a bridesmaid somewhere back inside a room wearing a gown shaped like a pastry ---- 13.316322326660156
#
# Query sentence: I sneak in and see your friends and her snotty little family all dressed in pastel and she is yelling at a bridesmaid somewhere back inside a room wearing a gown shaped like a pastry
# Nearest Neighbor Number 1: I'm on my guard for the rest of the world but with you, I know it's no goodAnd I could wait patiently but I really wish you wouldI run my fingers through your hair and watch the lights go wild ---- 15.084930419921875
#
# Query sentence: I sneak in and see your friends and her snotty little family all dressed in pastel and she is yelling at a bridesmaid somewhere back inside a room wearing a gown shaped like a pastry
# Nearest Neighbor Number 1: Gimme something that'll haunt me when you're not around ---- 15.610637664794922
